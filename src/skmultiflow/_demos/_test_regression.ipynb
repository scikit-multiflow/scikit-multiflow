# %%
from skmultiflow.evaluation import EvaluatePrequential
from skmultiflow.data import RegressionGenerator
from skmultiflow.trees import HoeffdingTreeRegressor
# %matplotlib notebook

# %% [markdown]
#     This demo demonstrates how to evaluate a regressor. The data stream used
#     is an instance of the RegressionGenerator, which feeds an instance from
#     sklearn's SGDRegressor.

# %%
# Setup stream generator
stream = RegressionGenerator(n_samples=40000)

# %%
# Setup model
regressor = HoeffdingTreeRegressor()

# %%
# Setup the evaluator
evaluator = EvaluatePrequential(pretrain_size=1, max_samples=40000, batch_size=1, n_wait=200, max_time=1000,
                                output_file='test_regression.csv', show_plot=True, metrics=['mean_square_error'])

# %%
# Evaluate
evaluator.evaluate(stream=stream, model=regressor)
# Out:
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#  #################### [100%] [192.03s]
# Processed samples: 40000
# Mean performance:
# M0 - MSE          : 8800.6955
# [HoeffdingTreeRegressor(binary_split=False, grace_period=200,
#                         leaf_prediction='perceptron', learning_ratio_const=True,
#                         learning_ratio_decay=0.001,
#                         learning_ratio_perceptron=0.02, max_byte_size=33554432,
#                         memory_estimate_period=1000000, nb_threshold=0,
#                         no_preprune=False, nominal_attributes=None,
#                         random_state=None, remove_poor_atts=False,
#                         split_confidence=1e-07, stop_mem_management=False,
#                         tie_threshold=0.05)]
